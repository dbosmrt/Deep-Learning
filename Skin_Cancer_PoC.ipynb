# %% [markdown]
# <a href="https://colab.research.google.com/github/dbosmrt/Deep-Learning/blob/main/Skin_Cancer_PoC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow

# %%
# Here I will work on annotating the data and then traning a CNN model to classifiy Skin cancer images from non cancer images.
